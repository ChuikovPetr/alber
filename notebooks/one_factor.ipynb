# %%
# %load_ext autoreload
# %autoreload 2



from ccf.one_factor import one_factor
import logging
from pathlib import Path
import pandas as pd
from typing import List

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s :: %(filename)s :: %(funcName)s :: %(message)s",
)

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 10_000)

# %%
base = '../../Storage/alber'

# %%
corr_frame = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_corr_frame_vars_60_corr_010.csv')

# %%
block_var = one_factor(
    features_path = Path(f'{base}/features.parquet.gzip'),
    count_folds = 10,
    block_var_path = Path(f'{base}/ret_1_10_folds_exp/analytics/result_rel.csv'),
    metrics = [
        ['count_boot_le_one', 'rel_diff_macro_lower_boot_95'], 
        [True, False]
    ],
    corr_frame_save_path = Path(f'{base}/ret_1_10_folds_exp/analytics/one_factor_corr_frame_vars_60_corr_05.csv'),
    block_var_save_path = Path(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_05.csv'),
    features_save_path = None,
    keys = ['time'],
    corr_frame = corr_frame
)
# Out:
# 2022-10-30 11:59:16,338 :: one_factor.py :: one_factor :: 2. Create df for one_factor selection - complete.
# ----------------------------------------------------------------------------------------------------
# Input threhold for count_boot_le_one metric for cut off: 100_000
# Initial count: 120;                             Delete count: 0;                             Remain count: 120
# Input y for continue or n for repeat: y
# ----------------------------------------------------------------------------------------------------
# Input threhold for rel_diff_macro_lower_boot_95 metric for cut off: -1.999745
# Initial count: 120;                             Delete count: 30;                             Remain count: 90
# Input y for continue or n for repeat: y
# Input y for continue or n for repeat cut off threhold choosing: y
# ----------------------------------------------------------------------------------------------------
# Input threhold for correlation for cut off: 0.5
# ...

# %%
block_var = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_05.csv')
block_var
# Out:
#                    new_var  count_boot_le_one  rel_diff_macro_lower_boot_95
# 0       stoch_k_price_21_1                  0                    100.000000
# 1        bid_ask_w_spread2               9327                     -0.065044
# 2   rel_stoch_price_21_1_3              10000                     -0.128866
# 3       rel_volume_ask_bid              10000                     -0.246555
# 4         volume_imbalance              10000                     -0.599778
# 5           rel_price_5_10              10000                     -0.624637
# 6                ask_size2              10000                     -0.664445
# 7                bid_size2              10000                     -0.669696
# 8      rel_volume_ask_bid1              10000                     -0.679684
# 9    log_return_mean_price              10000                     -0.760356
# 10             wap_balance              10000                     -0.761315
# ...

# %%
block_var = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_06.csv')
block_var
# Out:
#                    new_var  count_boot_le_one  rel_diff_macro_lower_boot_95
# 0       stoch_k_price_21_1                  0                    100.000000
# 1        bid_ask_w_spread2               9327                     -0.065044
# 2   rel_stoch_price_21_1_3              10000                     -0.128866
# 3       rel_volume_ask_bid              10000                     -0.246555
# 4           rel_price_5_20              10000                     -0.522492
# 5         volume_imbalance              10000                     -0.599778
# 6                ask_size2              10000                     -0.664445
# 7                bid_size2              10000                     -0.669696
# 8      rel_volume_ask_bid1              10000                     -0.679684
# 9    log_return_mean_price              10000                     -0.760356
# 10             wap_balance              10000                     -0.761315
# ...

# %%
block_var = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_07.csv')
block_var
# Out:
#                    new_var  count_boot_le_one  rel_diff_macro_lower_boot_95
# 0       stoch_k_price_21_1                  0                    100.000000
# 1        bid_ask_w_spread2               9327                     -0.065044
# 2   rel_stoch_price_21_1_3              10000                     -0.128866
# 3       rel_volume_ask_bid              10000                     -0.246555
# 4           rel_price_1_20              10000                     -0.462335
# 5         volume_imbalance              10000                     -0.599778
# 6               volume_bid              10000                     -0.625996
# 7                ask_size2              10000                     -0.664445
# 8                bid_size2              10000                     -0.669696
# 9      rel_volume_ask_bid1              10000                     -0.679684
# 10   log_return_mean_price              10000                     -0.760356
# ...

# %%
block_var = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_08.csv')
block_var
# Out:
#                    new_var  count_boot_le_one  rel_diff_macro_lower_boot_95
# 0       stoch_k_price_21_1                  0                    100.000000
# 1        bid_ask_w_spread2               9327                     -0.065044
# 2   rel_stoch_price_21_1_3              10000                     -0.128866
# 3       stoch_d_price_42_3              10000                     -0.237378
# 4       rel_volume_ask_bid              10000                     -0.246555
# 5           rel_price_1_20              10000                     -0.462335
# 6         volume_imbalance              10000                     -0.599778
# 7           rel_price_5_10              10000                     -0.624637
# 8               volume_bid              10000                     -0.625996
# 9                ask_size2              10000                     -0.664445
# 10               bid_size2              10000                     -0.669696
# ...

# %%
block_var = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_09.csv')
block_var
# Out:
#                    new_var  count_boot_le_one  rel_diff_macro_lower_boot_95
# 0       stoch_k_price_21_1                  0                    100.000000
# 1        bid_ask_w_spread2               9327                     -0.065044
# 2       stoch_k_price_42_1               9916                     -0.040432
# 3       stoch_k_price_14_1              10000                     -0.076206
# 4       stoch_d_price_21_3              10000                     -0.096349
# 5   rel_stoch_price_21_1_3              10000                     -0.128866
# 6   rel_stoch_price_42_1_3              10000                     -0.165567
# 7       rel_volume_ask_bid              10000                     -0.246555
# 8           rel_price_1_20              10000                     -0.462335
# 9           rel_price_5_20              10000                     -0.522492
# 10        volume_imbalance              10000                     -0.599778
# ...

# %%
block_var = pd.read_csv(f'{base}/ret_1_10_folds_exp/analytics/one_factor_block_vars_vars_60_corr_010.csv')
block_var
# Out:
#                    new_var  count_boot_le_one  rel_diff_macro_lower_boot_95
# 0       stoch_k_price_21_1                  0                    100.000000
# 1        bid_ask_w_spread2               9327                     -0.065044
# 2      rel_volume_ask_bid2               9358                     -0.065661
# 3       stoch_k_price_42_1               9916                     -0.040432
# 4       stoch_k_price_14_1              10000                     -0.076206
# 5       stoch_d_price_21_3              10000                     -0.096349
# 6       stoch_d_price_14_3              10000                     -0.103596
# 7   rel_stoch_price_21_1_3              10000                     -0.128866
# 8   rel_stoch_price_42_1_3              10000                     -0.165567
# 9   rel_stoch_price_14_1_3              10000                     -0.175372
# 10      stoch_d_price_42_3              10000                     -0.237378
# ...
