# %%
! pip install h5py

# %%
import pandas as pd
import h5py
import numpy as np

# %%
#data = pd.read_hdf('btcusd-h-30/data.h5', "/random")
f = h5py.File('btcusd-h-30/data.h5', 'r')
f
# Out:
# <HDF5 file "data.h5" (mode r)>

# %%
list(f.keys())
# Out:
# ['OB', 'Trades']

# %%
df
# Out:
#         0
# 0      OB
# 1  Trades

# %%
dset = f['OB']

# %%
dset
# Out:
# <HDF5 group "/OB" (5 members)>

# %%
for name in f:
    print(name)
# Out:
# OB
# Trades

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']))
df
# Out:
# <ipython-input-81-70e97b3045aa>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']))
#       0
# 0   Ask
# 1  AskV
# 2   Bid
# 3  BidV
# 4    TS

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['TS']))
df
# Out:
# <ipython-input-75-e687330e4cab>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['TS']))
#                     0
# 0        0.000000e+00
# 1        7.780000e+02
# 2        1.287000e+03
# 3        1.744000e+03
# 4        2.590000e+03
# ...               ...
# 9871637  6.479995e+09
# 9871638  6.479996e+09
# 9871639  6.479997e+09
# 9871640  6.479998e+09
# 9871641  6.479999e+09
#
# [9871642 rows x 1 columns]

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['Ask']))
df
# Out:
# <ipython-input-78-fb97e1d6ef8f>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['Ask']))
#               0        1        2        3        4        5        6   \
# 0        9792.39  9792.44  9792.47  9792.48  9792.67  9794.12  9794.13
# 1        9789.99  9790.19  9792.13  9792.35  9792.38  9792.39  9792.47
# 2        9789.99  9790.19  9792.13  9792.35  9792.38  9792.39  9792.47
# 3        9789.90  9789.98  9789.99  9790.19  9790.49  9792.13  9792.22
# 4        9789.90  9789.98  9789.99  9790.19  9790.49  9792.13  9792.22
# ...          ...      ...      ...      ...      ...      ...      ...
# ...

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['AskV']))
df
# Out:
# <ipython-input-80-d56f2730d613>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['AskV']))
#                0         1         2         3         4         5       6   \
# 0        0.057008  0.639431  1.739000  0.971500  0.700000  1.388600  0.1300
# 1        0.900000  0.700000  1.000000  0.660194  0.889299  0.057008  1.2507
# 2        0.900000  0.700000  1.000000  0.660194  0.889299  0.057008  1.2507
# 3        0.054463  1.502706  0.943620  0.700000  0.200000  1.000000  0.3274
# 4        0.054463  1.502706  0.943620  0.700000  0.200000  1.000000  0.3274
# ...

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')))
df

# %%
Res = pd.DataFrame(np.array(h5py.File('btcusd-h-30/result.h5')['Return']['Res']))
TS = pd.DataFrame(np.array(h5py.File('btcusd-h-30/result.h5')['Return']['TS']))
# Out:
# <ipython-input-69-819bd3a65658>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   Res = pd.DataFrame(np.array(h5py.File('btcusd-h-30/result.h5')['Return']['Res']))
# <ipython-input-69-819bd3a65658>:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   TS = pd.DataFrame(np.array(h5py.File('btcusd-h-30/result.h5')['Return']['TS']))

# %%
Res
# Out:
#                 0
# 0        0.000632
# 1        0.001178
# 2        0.001178
# 3        0.001182
# 4        0.001161
# ...           ...
# 9871637 -0.000138
# 9871638  0.000106
# 9871639  0.000038
# 9871640  0.000002
# 9871641  0.000000
#
# [9871642 rows x 1 columns]

# %%
TS
# Out:
#                     0
# 0        0.000000e+00
# 1        7.780000e+02
# 2        1.287000e+03
# 3        1.744000e+03
# 4        2.590000e+03
# ...               ...
# 9871637  6.479995e+09
# 9871638  6.479996e+09
# 9871639  6.479997e+09
# 9871640  6.479998e+09
# 9871641  6.479999e+09
#
# [9871642 rows x 1 columns]

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['TS']))
# Out:
# <ipython-input-58-81684d878d07>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['TS']))

# %%
df = df.retype({'0': ''})

# %%
df.dtypes
# Out:
# 0    float64
# dtype: object

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['Trades']['Price']))
# Out:
# <ipython-input-49-3e39f0cc8097>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['Trades']['Price']))

# %%
df
# Out:
#                     0
# 0         9783.854924
# 1         9789.988042
# 2         9789.980000
# 3         9789.900000
# 4         9782.090000
# ...               ...
# 13004174  8234.080000
# 13004175  8233.120000
# 13004176  8231.800000
# 13004177  8232.410000
# 13004178  8232.120000
#
# [13004179 rows x 1 columns]

# %%
df
# Out:
#                      0
# 0         2.730000e+02
# 1         9.660000e+02
# 2         9.970000e+02
# 3         1.287000e+03
# 4         1.287000e+03
# ...                ...
# 13004174  6.479993e+09
# 13004175  6.479995e+09
# 13004176  6.479997e+09
# 13004177  6.479999e+09
# 13004178  6.479999e+09
#
# [13004179 rows x 1 columns]

# %%
df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['Ask']))
# Out:
# <ipython-input-39-1a0edcdcbf30>:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   df = pd.DataFrame(np.array(h5py.File('btcusd-h-30/data.h5')['OB']['Ask']))

# %%
df
# Out:
#               0        1        2        3        4        5        6   \
# 0        9792.39  9792.44  9792.47  9792.48  9792.67  9794.12  9794.13
# 1        9789.99  9790.19  9792.13  9792.35  9792.38  9792.39  9792.47
# 2        9789.99  9790.19  9792.13  9792.35  9792.38  9792.39  9792.47
# 3        9789.90  9789.98  9789.99  9790.19  9790.49  9792.13  9792.22
# 4        9789.90  9789.98  9789.99  9790.19  9790.49  9792.13  9792.22
# ...          ...      ...      ...      ...      ...      ...      ...
# 9871637  8233.40  8234.50  8234.53  8234.54  8234.60  8234.99  8235.58
# 9871638  8233.13  8233.20  8233.33  8233.36  8233.37  8233.39  8233.40
# 9871639  8233.03  8233.12  8233.19  8233.20  8233.39  8234.38  8234.54
# 9871640  8232.42  8233.02  8233.19  8233.99  8234.05  8234.37  8234.38
# 9871641  8232.41  8232.42  8234.05  8234.34  8234.37  8234.38  8235.32
#
#               7        8        9   ...       20       21       22       23  \
# ...
