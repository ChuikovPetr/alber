# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import h5py
import numpy as np
from typing import List, Tuple
from pathlib import Path

from alber.load_data import read_order_book, read_trades, read_target
from alber.feature_generation import (
    book_preprocessor, 
    get_features_zscore, 
    get_features_ma, 
    get_features_stoch,
    retime_trades,
    decrease_mem_consuming
)
from alber.wf_splitting_data import create_oot, walk_forward_splitting
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 0. Parameters

# %%
base = Path('../../Storage/alber')

count_test = 985_564

train_val_ratio = 0.1
val_size = 440_000
num_folds = 10
folds_path = Path('ret_1_10_folds_exp')

test_path = Path('ret_1_test_folds_1_exp')

# %% [markdown]
# # 1. Load order book and trades data

# %%
ob = read_order_book(base / Path('data.h5'))
trades = read_trades(base / Path('data.h5'))
# Out:
# /share/pchuykov/alber/alber/load_data.py:59: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   trades = pd.merge(trades, sum_w, on=['time'])
# /share/pchuykov/alber/alber/load_data.py:59: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   trades = pd.merge(trades, sum_w, on=['time'])

# %%
ob.shape, trades.shape
# Out:
# ((9871642, 9), (12522917, 4))

# %%
ob.head()
# Out:
#      time  bid_price1  bid_price2  ask_price1  ask_price2  bid_size1  \
# 0     0.0     9787.75     9787.05     9792.39     9792.44   0.000264
# 1   778.0     9782.08     9782.07     9789.99     9790.19   1.080000
# 2  1287.0     9782.08     9782.07     9789.99     9790.19   1.080000
# 3  1744.0     9782.09     9782.08     9789.90     9789.98   0.646307
# 4  2590.0     9782.09     9782.08     9789.90     9789.98   0.646307
#
#    bid_size2  ask_size1  ask_size2
# 0   0.045246   0.057008   0.639431
# 1   0.068143   0.900000   0.700000
# 2   0.068143   0.900000   0.700000
# 3   0.091000   0.054463   1.502706
# 4   0.091000   0.054463   1.502706

# %%
trades.head()
# Out:
#      time        price      size  order_count  id  Ret_z  Sprd_z  Sprd_Up_z  \
# 0   273.0  9783.854924  0.225100            1   0    NaN     NaN        NaN
# 1   966.0  9789.988042  0.014648            1   0    NaN     NaN        NaN
# 2   997.0  9789.980000  0.021673            1   0    NaN     NaN        NaN
# 3  1287.0  9782.122815  0.357000            2   0    NaN     NaN        NaN
# 4  1380.0  9789.900000  0.001045            1   0    NaN     NaN        NaN
#
#    Sprd_Down_z        Money  ...  rel_stoch_price_42_1_3  stoch_k_size_14_1  \
# 0          NaN  2202.345743  ...                     NaN                NaN
# 1          NaN   143.403745  ...                     NaN                NaN
# 2          NaN   212.178237  ...                     NaN                NaN
# 3          NaN  3492.217845  ...                     NaN                NaN
# 4          NaN    10.230445  ...                     NaN                NaN
#
#    stoch_d_size_14_3  rel_stoch_size_14_1_3  stoch_k_size_21_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_21_3  rel_stoch_size_21_1_3  stoch_k_size_42_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_42_3  rel_stoch_size_42_1_3
# 0                NaN                    NaN
# 1                NaN                    NaN
# 2                NaN                    NaN
# 3                NaN                    NaN
# 4                NaN                    NaN
#
# [5 rows x 88 columns]

# %% [markdown]
# # 2. Feature generation

# %% [markdown]
# Book data

# %%
ob.shape
# Out:
# (9871642, 9)

# %%
ob_f = book_preprocessor(ob)

# %%
ob.shape
# Out:
# (9871642, 35)

# %%
ob.head()
# Out:
#      time  bid_price1  bid_price2  ask_price1  ask_price2  bid_size1  \
# 0     0.0     9787.75     9787.05     9792.39     9792.44   0.000264
# 1   778.0     9782.08     9782.07     9789.99     9790.19   1.080000
# 2  1287.0     9782.08     9782.07     9789.99     9790.19   1.080000
# 3  1744.0     9782.09     9782.08     9789.90     9789.98   0.646307
# 4  2590.0     9782.09     9782.08     9789.90     9789.98   0.646307
#
#    bid_size2  ask_size1  ask_size2         wap1  ...  abs_volume_imbalance  \
# 0   0.045246   0.057008   0.639431  9787.771388  ...              0.650929
# 1   0.068143   0.900000   0.700000  9786.394545  ...              0.451857
# 2   0.068143   0.900000   0.700000  9786.394545  ...              0.451857
# 3   0.091000   0.054463   1.502706  9789.293016  ...              0.819862
# 4   0.091000   0.054463   1.502706  9789.293016  ...              0.819862
#
#    rel_volume_ask_bid  rel_volume_ask_bid1  rel_volume_ask_bid2  \
# 0           14.302988           214.939394            13.132321
# 1            0.393555            -0.166667             9.272515
# 2            0.393555            -0.166667             9.272515
# 3            1.111968            -0.915732            15.513253
# 4            1.111968            -0.915732            15.513253
#
#    rel_volume_ask  rel_volume_bid  bid_ask_w_spread1  bid_ask_w_spread2  \
# 0       -0.910846       -0.994165         215.041763          13.140104
# 1        0.285714       14.849023          -0.165993           9.281042
# 2        0.285714       14.849023          -0.165993           9.281042
# 3       -0.963757        6.102275          -0.915665          15.526589
# 4       -0.963757        6.102275          -0.915665          15.526589
#
#    bid_w_spread  bid_w_ask
# 0     -0.994165  -0.910846
# 1     14.849040   0.285688
# 2     14.849040   0.285688
# 3      6.102282  -0.963757
# 4      6.102282  -0.963757
#
# [5 rows x 35 columns]

# %% [markdown]
# Trades data

# %%
trades['id'] = 0

# %%
# %%time
trades = get_features_zscore(trades)
# Out:
# Ret
# Sprd
# Sprd_Up
# Sprd_Down
# CPU times: user 5h 47min 7s, sys: 2min 39s, total: 5h 49min 47s
# Wall time: 5h 47min 38s

# %%
# %%time
trades = get_features_ma(trades)
# Out:
# price
# size
# order_count
# Money
# CPU times: user 15h 26min 20s, sys: 5min 17s, total: 15h 31min 37s
# Wall time: 15h 31min 41s

# %%
# %%time
trades = get_features_stoch(trades)
# Out:
# CPU times: user 11h 36min 32s, sys: 2min 21s, total: 11h 38min 54s
# Wall time: 11h 38min 57s

# %%
trades.head()
# Out:
#      time        price      size  order_count  id  Ret_z  Sprd_z  Sprd_Up_z  \
# 0   273.0  9783.854924  0.225100            1   0    NaN     NaN        NaN
# 1   966.0  9789.988042  0.014648            1   0    NaN     NaN        NaN
# 2   997.0  9789.980000  0.021673            1   0    NaN     NaN        NaN
# 3  1287.0  9782.122815  0.357000            2   0    NaN     NaN        NaN
# 4  1380.0  9789.900000  0.001045            1   0    NaN     NaN        NaN
#
#    Sprd_Down_z        Money  ...  rel_stoch_price_42_1_3  stoch_k_size_14_1  \
# 0          NaN  2202.345743  ...                     NaN                NaN
# 1          NaN   143.403745  ...                     NaN                NaN
# 2          NaN   212.178237  ...                     NaN                NaN
# 3          NaN  3492.217845  ...                     NaN                NaN
# 4          NaN    10.230445  ...                     NaN                NaN
#
#    stoch_d_size_14_3  rel_stoch_size_14_1_3  stoch_k_size_21_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_21_3  rel_stoch_size_21_1_3  stoch_k_size_42_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_42_3  rel_stoch_size_42_1_3
# 0                NaN                    NaN
# 1                NaN                    NaN
# 2                NaN                    NaN
# 3                NaN                    NaN
# 4                NaN                    NaN
#
# [5 rows x 88 columns]

# %%
trades.to_parquet(
    base / Path('trades.parquet.gzip'),
    compression="gzip",
)

# %% [markdown]
# Rescale trades feature to book time

# %%
trades_2 = retime_trades(trades, ob)

# %%
trades_2.shape
# Out:
# (9871642, 88)

# %%
trades_2.head()
# Out:
#      time        price      size  order_count  id  Ret_z  Sprd_z  Sprd_Up_z  \
# 0     0.0          NaN       NaN          NaN  -1    NaN     NaN        NaN
# 1   778.0  9783.854924  0.225100          1.0  -1    NaN     NaN        NaN
# 2  1287.0  9789.980000  0.021673          1.0  -1    NaN     NaN        NaN
# 3  1744.0  9789.900000  0.001045          1.0  -1    NaN     NaN        NaN
# 4  2590.0  9789.860000  0.010000          1.0  -1    NaN     NaN        NaN
#
#    Sprd_Down_z        Money  ...  rel_stoch_price_42_1_3  stoch_k_size_14_1  \
# 0          NaN          NaN  ...                     NaN                NaN
# 1          NaN  2202.345743  ...                     NaN                NaN
# 2          NaN   212.178237  ...                     NaN                NaN
# 3          NaN    10.230445  ...                     NaN                NaN
# 4          NaN    97.898600  ...                     NaN                NaN
#
#    stoch_d_size_14_3  rel_stoch_size_14_1_3  stoch_k_size_21_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_21_3  rel_stoch_size_21_1_3  stoch_k_size_42_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_42_3  rel_stoch_size_42_1_3
# 0                NaN                    NaN
# 1                NaN                    NaN
# 2                NaN                    NaN
# 3                NaN                    NaN
# 4                NaN                    NaN
#
# [5 rows x 88 columns]

# %%
ob.head()
# Out:
#      time  bid_price1  bid_price2  ask_price1  ask_price2  bid_size1  \
# 0     0.0     9787.75     9787.05     9792.39     9792.44   0.000264
# 1   778.0     9782.08     9782.07     9789.99     9790.19   1.080000
# 2  1287.0     9782.08     9782.07     9789.99     9790.19   1.080000
# 3  1744.0     9782.09     9782.08     9789.90     9789.98   0.646307
# 4  2590.0     9782.09     9782.08     9789.90     9789.98   0.646307
#
#    bid_size2  ask_size1  ask_size2         wap1  ...  rel_volume_ask_bid  \
# 0   0.045246   0.057008   0.639431  9787.771388  ...           14.302988
# 1   0.068143   0.900000   0.700000  9786.394545  ...            0.393555
# 2   0.068143   0.900000   0.700000  9786.394545  ...            0.393555
# 3   0.091000   0.054463   1.502706  9789.293016  ...            1.111968
# 4   0.091000   0.054463   1.502706  9789.293016  ...            1.111968
#
#    rel_volume_ask_bid1  rel_volume_ask_bid2  rel_volume_ask  rel_volume_bid  \
# 0           214.939394            13.132321       -0.910846       -0.994165
# 1            -0.166667             9.272515        0.285714       14.849023
# 2            -0.166667             9.272515        0.285714       14.849023
# 3            -0.915732            15.513253       -0.963757        6.102275
# 4            -0.915732            15.513253       -0.963757        6.102275
#
#    bid_ask_w_spread1  bid_ask_w_spread2  bid_w_spread  bid_w_ask  id
# 0         215.041763          13.140104     -0.994165  -0.910846  -1
# 1          -0.165993           9.281042     14.849040   0.285688  -1
# 2          -0.165993           9.281042     14.849040   0.285688  -1
# 3          -0.915665          15.526589      6.102282  -0.963757  -1
# 4          -0.915665          15.526589      6.102282  -0.963757  -1
#
# [5 rows x 36 columns]

# %%
trades.head()
# Out:
#      time        price      size  order_count  id  Ret_z  Sprd_z  Sprd_Up_z  \
# 0   273.0  9783.854924  0.225100            1   0    NaN     NaN        NaN
# 1   966.0  9789.988042  0.014648            1   0    NaN     NaN        NaN
# 2   997.0  9789.980000  0.021673            1   0    NaN     NaN        NaN
# 3  1287.0  9782.122815  0.357000            2   0    NaN     NaN        NaN
# 4  1380.0  9789.900000  0.001045            1   0    NaN     NaN        NaN
#
#    Sprd_Down_z        Money  ...  rel_stoch_price_42_1_3  stoch_k_size_14_1  \
# 0          NaN  2202.345743  ...                     NaN                NaN
# 1          NaN   143.403745  ...                     NaN                NaN
# 2          NaN   212.178237  ...                     NaN                NaN
# 3          NaN  3492.217845  ...                     NaN                NaN
# 4          NaN    10.230445  ...                     NaN                NaN
#
#    stoch_d_size_14_3  rel_stoch_size_14_1_3  stoch_k_size_21_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_21_3  rel_stoch_size_21_1_3  stoch_k_size_42_1  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
# 3                NaN                    NaN                NaN
# 4                NaN                    NaN                NaN
#
#    stoch_d_size_42_3  rel_stoch_size_42_1_3
# 0                NaN                    NaN
# 1                NaN                    NaN
# 2                NaN                    NaN
# 3                NaN                    NaN
# 4                NaN                    NaN
#
# [5 rows x 88 columns]

# %%
ob = ob.drop(['id'], axis=1)
trades_2 = trades_2.drop(['id'], axis=1)
features = pd.merge(ob, trades_2, on=['time'])

# %%
features.time.unique().shape, features.shape
# Out:
# ((9855646,), (9903634, 121))

# %%
features.tail()
# Out:
#                time  bid_price1  bid_price2  ask_price1  ask_price2  \
# 9903629  6479994731     8233.12     8230.80     8233.40     8234.50
# 9903630  6479995854     8229.38     8229.26     8233.13     8233.20
# 9903631  6479996824     8230.60     8229.70     8233.03     8233.12
# 9903632  6479997863     8231.80     8231.70     8232.42     8233.02
# 9903633  6479998786     8231.84     8231.80     8232.41     8232.42
#
#          bid_size1  bid_size2  ask_size1  ask_size2         wap1  ...  \
# 9903629   0.048584      0.001   0.500000   1.230785  8233.144798  ...
# 9903630   0.448800      0.001   0.642737   0.630000  8230.921863  ...
# 9903631   0.250000      0.375   0.064000   1.051843  8232.534713  ...
# 9903632   0.610000      0.015   0.014595   0.252026  8232.405512  ...
# 9903633   1.245423      0.490   0.243066   0.014595  8232.316921  ...
#
#          rel_stoch_price_42_1_3  stoch_k_size_14_1  stoch_d_size_14_3  \
# 9903629                2.999965           1.721196          36.996470
# 9903630                1.151818          39.933570          47.075554
# 9903631                1.151818          39.933570          47.075554
# 9903632                0.182523          12.129506          17.928091
# 9903633                0.182523          12.129506          17.928091
#
#          rel_stoch_size_14_1_3  stoch_k_size_21_1  stoch_d_size_21_3  \
# 9903629               0.046523           1.757695          16.977043
# 9903630               0.848285          37.449804          27.986023
# 9903631               0.848285          37.449804          27.986023
# 9903632               0.676561          11.346537          16.851345
# 9903633               0.676561          11.346537          16.851345
#
#          rel_stoch_size_21_1_3  stoch_k_size_42_1  stoch_d_size_42_3  \
# 9903629               0.103533           0.899231          16.718701
# 9903630               1.338156          18.000748          21.227038
# 9903631               1.338156          18.000748          21.227038
# 9903632               0.673327           5.526459           8.142146
# 9903633               0.673327           5.526459           8.142146
#
#          rel_stoch_size_42_1_3
# 9903629               0.053786
# 9903630               0.848006
# 9903631               0.848006
# 9903632               0.678739
# 9903633               0.678739
#
# [5 rows x 121 columns]

# %%
features = features.astype({'time': int})
features = features.drop_duplicates(['time']).reset_index(drop=True)

# %%
features.tail()
# Out:
#                time  bid_price1  bid_price2  ask_price1  ask_price2  \
# 9855641  6479994731     8233.12     8230.80     8233.40     8234.50
# 9855642  6479995854     8229.38     8229.26     8233.13     8233.20
# 9855643  6479996824     8230.60     8229.70     8233.03     8233.12
# 9855644  6479997863     8231.80     8231.70     8232.42     8233.02
# 9855645  6479998786     8231.84     8231.80     8232.41     8232.42
#
#          bid_size1  bid_size2  ask_size1  ask_size2         wap1  ...  \
# 9855641   0.048584      0.001   0.500000   1.230785  8233.144798  ...
# 9855642   0.448800      0.001   0.642737   0.630000  8230.921863  ...
# 9855643   0.250000      0.375   0.064000   1.051843  8232.534713  ...
# 9855644   0.610000      0.015   0.014595   0.252026  8232.405512  ...
# 9855645   1.245423      0.490   0.243066   0.014595  8232.316921  ...
#
#          rel_stoch_price_42_1_3  stoch_k_size_14_1  stoch_d_size_14_3  \
# 9855641                2.999965           1.721196          36.996470
# 9855642                1.151818          39.933570          47.075554
# 9855643                1.151818          39.933570          47.075554
# 9855644                0.182523          12.129506          17.928091
# 9855645                0.182523          12.129506          17.928091
#
#          rel_stoch_size_14_1_3  stoch_k_size_21_1  stoch_d_size_21_3  \
# 9855641               0.046523           1.757695          16.977043
# 9855642               0.848285          37.449804          27.986023
# 9855643               0.848285          37.449804          27.986023
# 9855644               0.676561          11.346537          16.851345
# 9855645               0.676561          11.346537          16.851345
#
#          rel_stoch_size_21_1_3  stoch_k_size_42_1  stoch_d_size_42_3  \
# 9855641               0.103533           0.899231          16.718701
# 9855642               1.338156          18.000748          21.227038
# 9855643               1.338156          18.000748          21.227038
# 9855644               0.673327           5.526459           8.142146
# 9855645               0.673327           5.526459           8.142146
#
#          rel_stoch_size_42_1_3
# 9855641               0.053786
# 9855642               0.848006
# 9855643               0.848006
# 9855644               0.678739
# 9855645               0.678739
#
# [5 rows x 121 columns]

# %%
features.shape
# Out:
# (9855646, 121)

# %%
features.dtypes
# Out:
# time                       int64
# bid_price1               float64
# bid_price2               float64
# ask_price1               float64
# ask_price2               float64
#                           ...
# stoch_d_size_21_3        float64
# rel_stoch_size_21_1_3    float64
# stoch_k_size_42_1        float64
# stoch_d_size_42_3        float64
# rel_stoch_size_42_1_3    float64
# Length: 121, dtype: object

# %%
features = decrease_mem_consuming(features, ['time'])

# %%
features.dtypes
# Out:
# time                       int64
# bid_price1               float32
# bid_price2               float32
# ask_price1               float32
# ask_price2               float32
#                           ...
# stoch_d_size_21_3        float32
# rel_stoch_size_21_1_3    float32
# stoch_k_size_42_1        float32
# stoch_d_size_42_3        float32
# rel_stoch_size_42_1_3    float32
# Length: 121, dtype: object

# %%
features.tail()
# Out:
#                time   bid_price1   bid_price2   ask_price1   ask_price2  \
# 9855641  6479994731  8233.120117  8230.799805  8233.400391  8234.500000
# 9855642  6479995854  8229.379883  8229.259766  8233.129883  8233.200195
# 9855643  6479996824  8230.599609  8229.700195  8233.030273  8233.120117
# 9855644  6479997863  8231.799805  8231.700195  8232.419922  8233.019531
# 9855645  6479998786  8231.839844  8231.799805  8232.410156  8232.419922
#
#          bid_size1  bid_size2  ask_size1  ask_size2         wap1  ...  \
# 9855641   0.048584      0.001   0.500000   1.230785  8233.144531  ...
# 9855642   0.448800      0.001   0.642737   0.630000  8230.921875  ...
# 9855643   0.250000      0.375   0.064000   1.051843  8232.535156  ...
# 9855644   0.610000      0.015   0.014595   0.252026  8232.405273  ...
# 9855645   1.245423      0.490   0.243066   0.014595  8232.317383  ...
#
#          rel_stoch_price_42_1_3  stoch_k_size_14_1  stoch_d_size_14_3  \
# 9855641                2.999965           1.721196          36.996471
# 9855642                1.151818          39.933571          47.075554
# 9855643                1.151818          39.933571          47.075554
# 9855644                0.182523          12.129506          17.928091
# 9855645                0.182523          12.129506          17.928091
#
#          rel_stoch_size_14_1_3  stoch_k_size_21_1  stoch_d_size_21_3  \
# 9855641               0.046523           1.757695          16.977043
# 9855642               0.848285          37.449802          27.986023
# 9855643               0.848285          37.449802          27.986023
# 9855644               0.676561          11.346537          16.851345
# 9855645               0.676561          11.346537          16.851345
#
#          rel_stoch_size_21_1_3  stoch_k_size_42_1  stoch_d_size_42_3  \
# 9855641               0.103533           0.899231          16.718700
# 9855642               1.338156          18.000748          21.227037
# 9855643               1.338156          18.000748          21.227037
# 9855644               0.673327           5.526459           8.142146
# 9855645               0.673327           5.526459           8.142146
#
#          rel_stoch_size_42_1_3
# 9855641               0.053786
# 9855642               0.848006
# 9855643               0.848006
# 9855644               0.678739
# 9855645               0.678739
#
# [5 rows x 121 columns]

# %%
features.to_parquet(
    base / Path('features.parquet.gzip'),
    compression="gzip",
)

# %% [markdown]
# # 3. Create vitrine (split into train/test)

# %%
features.shape
# Out:
# (9855646, 121)

# %%
vitrine = features[['time']]
target = read_target(base / Path('result.h5'))
vitrine = pd.merge(vitrine, target, on=['time'])

vitrine = create_oot(vitrine, count_test)
# Out:
# Splitting vitrine into train/test:
# train_min_time == 0, train_max_time == 5838737647
# test_min_time == 5838738540, test_max_time == 6479998786
# unique_times_train == 8870082,
# unique_times_test == 985564,

# %%
vitrine.shape
# Out:
# (9855646, 3)

# %%
vitrine.query('segment == "train"').shape, vitrine.query('segment == "test"').shape
# Out:
# ((8870082, 3), (985564, 3))

# %%
8870082 // 2, 8870082 // 2 // 10, 8870082 // 2 // 10 * 3
# Out:
# (4435041, 443504, 1330512)

# %%
vitrine.to_parquet(
    base / Path('vitrine.parquet.gzip'),
    compression="gzip",
)

# %% [markdown]
# # 4. Split into folds

# %%
base_vitrine = vitrine.query('segment == "train"').reset_index(drop=True)

walk_forward_splitting(
    base_vitrine,
    train_val_ratio,
    val_size,
    num_folds,
    base,
    folds_path,
)
# Out:
# fold №1
# train::
#  len == 4023074, min == 0, max == 2843965736
# val-train::
#  len == 447008, min == 2668, max == 2843934808
# val::
#  len == 440000, min == 2843966657, max == 3141326865
#
#
#
# fold №2
# train::
#  len == 4419074, min == 0, max == 3141326865
# val-train::
#  len == 491008, min == 13784, max == 3141326232
# val::
#  len == 440000, min == 3141327748, max == 3427921761
#
#
#
# fold №3
# train::
#  len == 4815074, min == 0, max == 3427921761
# val-train::
#  len == 535008, min == 17802, max == 3427916644
# val::
#  len == 440000, min == 3427922491, max == 3724779876
#
#
#
# fold №4
# train::
#  len == 5211074, min == 0, max == 3724779876
# val-train::
#  len == 579008, min == 14856, max == 3724778889
# val::
#  len == 440000, min == 3724780909, max == 4045110033
#
#
#
# fold №5
# train::
#  len == 5607074, min == 0, max == 4045110033
# val-train::
#  len == 623008, min == 3736, max == 4045104673
# val::
#  len == 440000, min == 4045110540, max == 4327365709
#
#
#
# fold №6
# train::
#  len == 6003074, min == 0, max == 4327365709
# val-train::
#  len == 667008, min == 778, max == 4327361693
# val::
#  len == 440000, min == 4327366293, max == 4625014695
#
#
#
# fold №7
# train::
#  len == 6399074, min == 0, max == 4625013796
# val-train::
#  len == 711008, min == 9854, max == 4625014695
# val::
#  len == 440000, min == 4625015667, max == 4922731681
#
#
#
# fold №8
# train::
#  len == 6795074, min == 0, max == 4922731681
# val-train::
#  len == 755008, min == 13784, max == 4922730868
# val::
#  len == 440000, min == 4922732197, max == 5239060818
#
#
#
# fold №9
# train::
#  len == 7191074, min == 0, max == 5239060818
# val-train::
#  len == 799008, min == 1287, max == 5239050808
# val::
#  len == 440000, min == 5239061387, max == 5534829778
#
#
#
# fold №10
# train::
#  len == 7587074, min == 0, max == 5534829778
# val-train::
#  len == 843008, min == 2668, max == 5534825952
# val::
#  len == 440000, min == 5534830875, max == 5838737647

# %%
base_vitrine = vitrine.reset_index(drop=True)

walk_forward_splitting(
    base_vitrine,
    train_val_ratio,
    count_test,
    1,
    base,
    test_path,
)
# Out:
# fold №1
# train::
#  len == 7983074, min == 0, max == 5838737647
# val-train::
#  len == 887008, min == 5780, max == 5838736765
# val::
#  len == 985564, min == 5838738540, max == 6479998786

# %%
Splitting vitrine into train/test:
train_min_time == 0, train_max_time == 5838737647
test_min_time == 5838738540, test_max_time == 6479998786
unique_times_train == 8870082, 
unique_times_test == 985564,
